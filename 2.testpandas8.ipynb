# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('example')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('My_output')

# %%
pd.read_csv('My_output')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_csv('My_output',index=False)
pd.read_csv('My_output')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
dfe = pd.read_excel('Excel_Sample.xlsx',sheet_name='Sheet1')
dfe
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
dfe.drop('Unnamed: 0',axis=1,inplace=True)

# %%
dfe
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
dfe.to_excel('exl_smpl2.xlsx',sheet_name='s1')

# %%
pd.read_excel('exl_smpl2.xlsx',sheet_name='s1').drop('Unnamed: 0',axis=1)
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
dfh = pd.read_html('https://en.wikipedia.org/wiki/The_World%27s_Billionaires')

# %%
dfh[2]
# Out:
#    No.                      Name Net worth (USD)  Age    Nationality  \
# 0    1                Jeff Bezos    $177 billion   57  United States
# 1    2                 Elon Musk    $151 billion   49  United States
# 2    3  Bernard Arnault & family    $150 billion   72         France
# 3    4                Bill Gates    $124 billion   65  United States
# 4    5           Mark Zuckerberg     $97 billion   36  United States
# 5    6            Warren Buffett     $96 billion   90  United States
# 6    7             Larry Ellison     $93 billion   76  United States
# 7    8                Larry Page   $91.5 billion   48  United States
# 8    9               Sergey Brin     $89 billion   47  United States
# 9   10             Mukesh Ambani   $84.5 billion   63          India
#
#    Source(s) of wealth
# 0               Amazon
# 1        Tesla, SpaceX
# 2                 LVMH
# 3            Microsoft
# 4       Meta Platforms
# 5   Berkshire Hathaway
# 6   Oracle Corporation
# ...

# %%
dfh = dfh[2]

# %%
dfh.set_index('No.')
# Out:
#                          Name Net worth (USD)  Age    Nationality  \
# No.
# 1                  Jeff Bezos    $177 billion   57  United States
# 2                   Elon Musk    $151 billion   49  United States
# 3    Bernard Arnault & family    $150 billion   72         France
# 4                  Bill Gates    $124 billion   65  United States
# 5             Mark Zuckerberg     $97 billion   36  United States
# 6              Warren Buffett     $96 billion   90  United States
# 7               Larry Ellison     $93 billion   76  United States
# 8                  Larry Page   $91.5 billion   48  United States
# 9                 Sergey Brin     $89 billion   47  United States
# 10              Mukesh Ambani   $84.5 billion   63          India
#
#      Source(s) of wealth
# No.
# 1                 Amazon
# 2          Tesla, SpaceX
# 3                   LVMH
# 4              Microsoft
# 5         Meta Platforms
# 6     Berkshire Hathaway
# 7     Oracle Corporation
# ...

# %%
dfh.groupby('Nationality').describe()
# Out:
#                 No.                                                   Age  \
#               count   mean       std   min   25%   50%    75%   max count
# Nationality
# France          1.0   3.00       NaN   3.0   3.0   3.0   3.00   3.0   1.0
# India           1.0  10.00       NaN  10.0  10.0  10.0  10.00  10.0   1.0
# United States   8.0   5.25  2.815772   1.0   3.5   5.5   7.25   9.0   8.0
#
#
#                mean        std   min    25%   50%    75%   max
# Nationality
# France         72.0        NaN  72.0  72.00  72.0  72.00  72.0
# India          63.0        NaN  63.0  63.00  63.0  63.00  63.0
# United States  58.5  17.655432  36.0  47.75  53.0  67.75  90.0

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')
